# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("Investor_Sentiment.xlsx",sheet_name='DATA')
df['Date']=pd.to_datetime(df['Date'],format='%Y%m')

# %%
columns=['Date','SENT^ ','SENT','pdnd','ripo','nipo','cefd','s','indpro','consdur','consnon','consserv','recess','employ','cpi']
for t in columns:
    for i in range(732):
        if (df[t][i]=='.'):
            df[t][i]=np.nan
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df
# Out:
#           Date    SENT^       SENT     pdnd  ripo nipo     cefd          s  \
# 0   1958-01-01       NaN       NaN      NaN   NaN  NaN      NaN        NaN
# 1   1958-02-01       NaN       NaN      NaN   NaN  NaN      NaN        NaN
# 2   1958-03-01       NaN       NaN      NaN   NaN  NaN      NaN        NaN
# 3   1958-04-01       NaN       NaN      NaN   NaN  NaN      NaN        NaN
# 4   1958-05-01       NaN       NaN      NaN   NaN  NaN      NaN        NaN
# ..         ...       ...       ...      ...   ...  ...      ...        ...
# 727 2018-08-01 -0.132965 -0.237034 -9.61548  11.4   15  7.15475   0.078317
# 728 2018-09-01 -0.209843 -0.294292 -8.56591  26.1   24  7.45249  0.0824277
# 729 2018-10-01  -0.15722 -0.319598 -7.08007  21.3   27  11.0125  0.0792014
# 730 2018-11-01 -0.232775 -0.362102 -8.87295   0.9   11  10.2223   0.079705
# 731 2018-12-01 -0.282087 -0.409961 -8.78468  -1.4    9  10.8992  0.0810684
#
#        indpro consdur consnon consserv  recess  employ      cpi
# ...

# %%
df.to_csv("../Investor_Sentiment.csv",index = None)
